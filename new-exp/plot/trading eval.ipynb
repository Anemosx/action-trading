# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

plt.figure(figsize=(32,18))

df = pd.read_csv('C:/Users/Arno/contracting-agents/new-exp/csv-files/trading-values-20191221-14-20-27.csv')

df = df.loc[-50 < df.reward]

plot = sns.boxplot(x="agent", y="reward", hue="trading_steps", data=df, palette="Set1")
fig = plot.get_figure()
fig.savefig('hist.png')
plt.show()
