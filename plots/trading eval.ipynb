# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

plt.figure(figsize=(64,36))

df = pd.read_csv('C:/Users/Arno/contracting-agents/exp-trading/mark up - 20191223-16-52-06/csv files/values 20191223-18-33-34.csv')

df = df.loc[-5 < df.reward]

plot = sns.boxplot(x="agent", y="reward", hue="mark_up", data=df, palette="Set1")
fig = plot.get_figure()
fig.savefig('hist.png')
plt.show()
