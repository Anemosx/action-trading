# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

plt.figure(figsize=(32,18))

df = pd.read_csv('C:/Users/Arno/contracting-agents/exp-trading/trading steps - 20191227-15-20-55/evaluation files/values 20191227-16-19-21.csv')

df = df.loc[-15 < df.reward]

plot = sns.boxplot(x="agent", y="reward", hue="trading_steps", data=df, palette="Set1")
fig = plot.get_figure()
fig.savefig('hist.png')
plt.show()
