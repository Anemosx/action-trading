# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

plt.figure(figsize=(16,9))

str_dir = 'trading steps - tr mode 0 - 20200113-13-21-14'
value_dir = 'values 20200113-15-47-18'

df = pd.read_csv('C:/Users/Arno/contracting-agents/exp-trading/' + str_dir + '/evaluation files/' + value_dir + '.csv')

#df = df.loc[df.trading_steps == 1]
#df = df.loc[df.mark_up == 1.25]
# df = df.loc[df.number_trades == 7]
df = df.loc[df.agent != 'a-1']
df = df.loc[df.agent != 'a-2']
df = df.loc[df.episode_steps <= 100]

# plot = sns.boxplot(x="agent", y="reward", hue="number_trades", data=df, palette="Set1")

# plot = sns.boxplot(x="agent", y="reward", hue="mark_up", data=df, palette="Set1")

plot = sns.boxplot(x="agent", y="reward", hue="trading_steps", data=df, palette="Set1")

plot.set(ylim=(-30, 10))

fig = plot.get_figure()
fig.savefig('hist.png')
plt.show()
